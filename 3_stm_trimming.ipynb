# %%
from langgraph.graph import StateGraph, START, MessagesState
from langgraph.checkpoint.memory import InMemorySaver
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain_core.messages.utils import trim_messages,count_tokens_approximately

# %%
load_dotenv()
# Out:
# True

# %%
load_dotenv()
from langchain_groq import ChatGroq
# Model
model = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0.1)

# %%
MAX_TOKENS = 150

# %%
def call_model(state: MessagesState):
    
    # Trim conversation history -> last N messages that fit within the token budget
    messages = trim_messages(
        state["messages"],
        strategy="last",                      
        token_counter=count_tokens_approximately,
        max_tokens=MAX_TOKENS
    )

    print('Current Token Count ->', count_tokens_approximately(messages=messages))

    for message in messages:
        print(message.content)

    response = model.invoke(messages)

    return {"messages": [response]}

# %%
builder = StateGraph(MessagesState)
builder.add_node("call_model", call_model)
builder.add_edge(START, "call_model")

# %%
checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
graph

# %%
config = {"configurable": {"thread_id": "chat-1"}}

result = graph.invoke(
    {"messages": [{"role": "user", "content": "Hi, my name is Sujat."}]},
    config,
)

result["messages"][-1].content
# Out:
# Current Token Count -> 30
# Hi, my name is Sujat.
# Hi, my name is Sujat.
# Hi, my name is Sujat.
# 'Hello Sujat! Nice to meet you. How can I assist you today?'

# %%
result = graph.invoke(
    {"messages": [{"role": "user", "content": "I am learning LangGraph."}]},
    config,
)

result["messages"][-1].content
# Out:
# Current Token Count -> 60
# Hi, my name is Sujat.
# Hi, my name is Sujat.
# Hi, my name is Sujat.
# Hello Sujat! Nice to meet you. How can I assist you today?
# I am learning LangGraph.
# 'That’s great! LangGraph is a powerful framework for building composable, state‑driven LLM applications. Here’s a quick roadmap to get you up to speed, plus some hands‑on examples you can try right away.\n\n---\n\n## 1️⃣ Core Concepts at a Glance\n\n| Concept | What It Is | Why It Matters |\n|---------|------------|----------------|\n| **Node** | A reusable “step” that can call an LLM, run a tool, or perform any Python logic. | Encapsulates a single piece of functionality. |\n| **Edge** | A directed connection that tells the graph how to move from one node to the next, optionally based on conditions. | Enables branching, loops, and dynamic flow. |\n| **State** | A mutable dictionary (or Pydantic model) that travels with the graph, holding inputs, intermediate results, and metadata. | Gives every node access to the same context, making coordination easy. |\n| **Graph** | The orchestrator that wires nodes & edges together and runs the execution loop. | Turns a collection of isolated functions into a coherent workflow. |\n| **Checkpoint / Persistence** | Ability to serialize the current state and resume later. | Crucial for long‑running or user‑interrupted sessions. |\n\n---\n\n## 2️⃣ Minimal “Hello‑World” Example\n\n```python\nfrom langgraph import Graph, Node, Edge, State\n\n# 1️⃣ Define a simple node\ndef greet(state: State) -> State:\n    name = state.get("name", "world")\n    state["greeting"] = f"Hello, {name}!"\n    return state\n\n# 2️⃣ Wrap it as a Node object\ngreet_node = Node(fn=greet, name="greet")\n\n# 3️⃣ Build the graph (single node → end)\ngraph = Graph(\n    nodes=[greet_node],\n    edges=[Edge(source="greet", target="END")],\n    start_node="greet"\n)\n\n# 4️⃣ Run it\ninitial_state = State({"name": "Sujat"})\nfinal_state = graph.run(initial_state)\n\nprint(final_state["greeting"])   # → Hello, Sujat!\n```\n\n*Key takeaways*:  \n- Nodes are just plain Python callables that receive and return a `State`.  \n- The graph’s `run` method walks the edges automatically.  \n- `END` is a built‑in sentinel that stops execution.\n\n---\n\n## 3️⃣ Adding an LLM Call\n\nLet’s integrate OpenAI’s `gpt‑4o-mini` (or any compatible provider) to generate a short bio.\n\n```python\nimport os\nfrom openai import OpenAI\nfrom langgraph import Node, Edge, Graph, State\n\nclient = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))\n\ndef generate_bio(state: State) -> State:\n    prompt = f"""Write a 2‑sentence professional bio for a person named {state["name"]}.\n    Include their role as a software engineer and a hobby they love."""\n    response = client.chat.completions.create(\n        model="gpt-4o-mini",\n        messages=[{"role": "user", "content": prompt}],\n        temperature=0.7,\n    )\n    state["bio"] = response.choices[0].message.content.strip()\n    return state\n\nbio_node = Node(fn=generate_bio, name="bio")\ngraph = Graph(\n    nodes=[bio_node],\n    edges=[Edge(source="bio", target="END")],\n    start_node="bio"\n)\n\nprint(graph.run(State({"name": "Sujat"}))["bio"])\n```\n\n**What you see**:  \n- The node calls the LLM, stores the result in the shared state, and passes it forward.  \n- You can swap the LLM provider or model without touching the rest of the graph.\n\n---\n\n## 4️⃣ Branching & Conditional Logic\n\nSuppose you want to ask the user whether they’d like a *short* or *detailed* bio, then route accordingly.\n\n```python\ndef ask_preference(state: State) -> State:\n    # In a real app this could be a UI prompt; here we just simulate.\n    state["detail"] = "short"   # or "detailed"\n    return state\n\ndef short_bio(state: State) -> State:\n    # reuse generate_bio but with a tighter prompt\n    prompt = f"Write a ONE‑sentence bio for {state[\'name\']}."\n    # ... call LLM as before ...\n    # (omitted for brevity)\n    return state\n\ndef detailed_bio(state: State) -> State:\n    prompt = f"Write a FOUR‑sentence bio for {state[\'name\']}, mentioning career, achievements, and a hobby."\n    # ... call LLM ...\n     ...

# %%
result = graph.invoke(
    {"messages": [{"role": "user", "content": "Can you explain short term memory?"}]},
    config,
)

result["messages"][-1].content
# Out:
# Current Token Count -> 13
# Can you explain short term memory?
# '**Short‑term memory (STM)** is a mental system that holds a small amount of information in an active, readily accessible state for a brief period of time—typically on the order of seconds to a minute. It’s the “scratch‑pad” of the brain that lets you keep track of what you’re doing right now, such as remembering a phone number long enough to dial it or holding the last few words of a sentence while you understand its meaning.\n\nBelow is a concise overview of the key features, mechanisms, and practical implications of short‑term memory.\n\n---\n\n## 1. Core Characteristics\n\n| Feature | Typical Value | What It Means |\n|---------|----------------|----------------|\n| **Capacity** | 7\u202f±\u202f2 items (Miller’s classic estimate) | Most people can hold about 5–9 discrete “chunks” of information at once. A “chunk” can be a single digit, a word, or a meaningful group (e.g., a familiar acronym). |\n| **Duration** | 15–30\u202fseconds without rehearsal | If you don’t actively repeat or rehearse the information, it fades quickly. |\n| **Encoding** | Primarily **acoustic** (sound) and **visual** (spatial) | You tend to remember a string of numbers by hearing them (acoustic) or a pattern of shapes by seeing them (visual). |\n| **Retrieval** | Immediate, automatic | Because the information is still “online,” you can pull it out with little effort. |\n\n---\n\n## 2. How It Works: The Process Flow\n\n1. **Sensory Input** – Raw data from the senses (e.g., hearing a spoken word) first lands in **sensory memory** (a very brief buffer lasting <\u202f1\u202fsecond).  \n2. **Attention & Transfer** – If you attend to the stimulus, it moves into short‑term memory.  \n3. **Maintenance (Rehearsal)** – You can keep the info alive by:\n   - **Subvocal rehearsal** (silently repeating a phone number).  \n   - **Chunking** (grouping digits into meaningful units).  \n4. **Decay or Displacement** – Without rehearsal, the trace fades (decay). New incoming items can also push older ones out (interference).  \n5. **Encoding to Long‑Term Memory** – With sufficient rehearsal and meaningful connections, the information may be consolidated into long‑term memory (LTM) via processes like **semantic encoding** and **sleep‑dependent consolidation**.\n\n---\n\n## 3. Brain Structures Involved\n\n| Region | Role in STM |\n|--------|-------------|\n| **Prefrontal Cortex (PFC)** | Executive control, manipulation of information (working memory). |\n| **Parietal Cortex** | Spatial and attentional aspects of STM. |\n| **Temporal Lobe (especially the auditory cortex)** | Acoustic encoding of verbal material. |\n| **Hippocampus** | Not essential for pure STM, but crucial for transferring information to LTM. |\n| **Basal Ganglia & Cerebellum** | Support procedural aspects of rehearsal (e.g., motor planning for subvocal speech). |\n\nNeuroimaging studies show that when you hold a string of letters in mind, the dorsolateral prefrontal cortex lights up, reflecting the active maintenance of that information.\n\n---\n\n## 4. Short‑Term vs. Working Memory\n\n- **Short‑term memory** is often used as a synonym for the *storage* component of the system.\n- **Working memory** expands the concept to include *manipulation* of the stored information (e.g., solving a mental arithmetic problem).  \n  - Baddeley’s model of working memory includes:\n    1. **Phonological loop** (verbal STM).  \n    2. **Visuospatial sketchpad** (visual‑spatial STM).  \n    3. **Central executive** (attention control).  \n    4. **Episodic buffer** (integrates information across modalities).\n\nThus, STM can be thought of as the “raw storage” part of a broader working‑memory system.\n\n---\n\n## 5. Factors That Influence STM Performance\n\n| Factor | Effect |\n|--------|--------|\n| **Chunking** | Increases effective capacity (e.g., remembering “1776” as a single year rather than four separate digits). |\n| **Rehearsal** | Extends duration; the classic “repeat‑until‑you‑forget” strategy. |\n| **Interferenc ...

# %%
result = graph.invoke(
    {"messages": [{"role": "user", "content": "What is my name?"}]},
    config,
)

result["messages"][-1].content
# Out:
# Current Token Count -> 8
# What is my name?
# 'I don’t have any information about your name. If you’d like me to address you a certain way, just let me know!'

# %%
for item in graph.get_state({"configurable": {"thread_id": "chat-1"}}).values['messages']:
    print(item.content)
    print('-'*120)
# Out:
# Hi, my name is Sujat.
# ------------------------------------------------------------------------------------------------------------------------
# Hi, my name is Sujat.
# ------------------------------------------------------------------------------------------------------------------------
# Hi, my name is Sujat.
# ------------------------------------------------------------------------------------------------------------------------
# Hello Sujat! Nice to meet you. How can I assist you today?
# ------------------------------------------------------------------------------------------------------------------------
# I am learning LangGraph.
# ------------------------------------------------------------------------------------------------------------------------
# That’s great! LangGraph is a powerful framework for building composable, state‑driven LLM applications. Here’s a quick roadmap to get you up to speed, plus some hands‑on examples you can try right away.
#
# ---
#
# ## 1️⃣ Core Concepts at a Glance
#
# | Concept | What It Is | Why It Matters |
# |---------|------------|----------------|
# | **Node** | A reusable “step” that can call an LLM, run a tool, or perform any Python logic. | Encapsulates a single piece of functionality. |
# | **Edge** | A directed connection that tells the graph how to move from one node to the next, optionally based on conditions. | Enables branching, loops, and dynamic flow. |
# | **State** | A mutable dictionary (or Pydantic model) that travels with the graph, holding inputs, intermediate results, and metadata. | Gives every node access to the same context, making coordination easy. |
# | **Graph** | The orchestrator that wires nodes & edges together and runs the execution loop. | Turns a collection of isolated functions into a coherent workflow. |
# | **Checkpoint / Persistence** | Ability to serialize the current state and resume later. | Crucial for long‑running or user‑interrupted sessions. |
#
# ---
#
# ## 2️⃣ Minimal “Hello‑World” Example
#
# ```python
# from langgraph import Graph, Node, Edge, State
#
# # 1️⃣ Define a simple node
# def greet(state: State) -> State:
#     name = state.get("name", "world")
#     state["greeting"] = f"Hello, {name}!"
#     return state
#
# # 2️⃣ Wrap it as a Node object
# greet_node = Node(fn=greet, name="greet")
#
# # 3️⃣ Build the graph (single node → end)
# graph = Graph(
#     nodes=[greet_node],
#     edges=[Edge(source="greet", target="END")],
#     start_node="greet"
# )
#
# # 4️⃣ Run it
# initial_state = State({"name": "Sujat"})
# final_state = graph.run(initial_state)
#
# print(final_state["greeting"])   # → Hello, Sujat!
# ```
#
# *Key takeaways*:
# - Nodes are just plain Python callables that receive and return a `State`.
# - The graph’s `run` method walks the edges automatically.
# - `END` is a built‑in sentinel that stops execution.
#
# ---
#
# ## 3️⃣ Adding an LLM Call
#
# Let’s integrate OpenAI’s `gpt‑4o-mini` (or any compatible provider) to generate a short bio.
#
# ```python
# import os
# from openai import OpenAI
# from langgraph import Node, Edge, Graph, State
#
# client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
#
# def generate_bio(state: State) -> State:
#     prompt = f"""Write a 2‑sentence professional bio for a person named {state["name"]}.
#     Include their role as a software engineer and a hobby they love."""
#     response = client.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[{"role": "user", "content": prompt}],
#         temperature=0.7,
#     )
#     state["bio"] = response.choices[0].message.content.strip()
#     return state
#
# bio_node = Node(fn=generate_bio, name="bio")
# graph = Graph(
#     nodes=[bio_node],
#     edges=[Edge(source="bio", target="END")],
#     start_node="bio"
# )
#
# print(graph.run(State({"name": "Sujat"}))["bio"])
# ```
#
# **What you see**:
# - The node calls the LLM, stores the result in the shared state, and passes it forward.
# - You can swap the LLM provider or model without touching the rest of the graph.
#
# ---
#
# ## 4️⃣ Branching & Conditional Logic
#
# Suppose you want to ask the user whether they’d like a *short* or *detailed* bio, then route accordingly.
#
# ```python
# def ask_preference(state: State) -> State:
#     # In a real app this could be a UI prompt; here we just simulate.
#     state["detail"] = "short"   # or "detailed"
#     return state
#
# def short_bio(state: State) -> State:
#     # reuse generate_bio but with a tighter prompt
#     prompt = f"Write a ONE‑sentence bio for {state['name']}."
#     # ... call LLM as before ...
#     # (omitted for brevity)
#     return state
#
# def detailed_bio(state: State) -> State:
#     prompt = f"Write a FOUR‑sentence bio for {state['name']}, mentioning career, achievements, and a hobby."
#     # ... call LLM ...
#     return state
#
# # Nodes
# ask_node = Node(fn=ask_preference, name="ask")
# short_node = Node(fn=short_bio, name="short")
# detailed_node = Node(fn=detailed_bio, name="detailed")
#
# # Conditional edges
# edges = [
#     Edge(source="ask", target="short", condition=lambda s: s["detail"] == "short"),
#     Edge(source="ask", target="detailed", condition=lambda s: s["detail"] == "detailed"),
#     Edge(source="short", target="END"),
#     Edge(source="detailed", target="END"),
# ]
#
# graph = Graph(
#     nodes=[ask_node, short_node, detailed_node],
#     edges=edges,
#     start_node="ask"
# )
#
# print(graph.run(State({"name": "Sujat"})))
# ```
#
# **Why this matters**:
# - Edges can carry a `condition` callable that inspects the current state.
# - This gives you classic “if/else” flow without hard‑coding branches inside nodes.
#
# ---
#
# ## 5️⃣ Loops & Retry Patterns
#
# LangGraph makes it easy to retry a node until a quality check passes.
#
# ```python
# def quality_check(state: State) -> State:
#     # Very naive check: ensure the bio contains the word "engineer"
#     if "engineer" not in state.get("bio", "").lower():
#         state["needs_retry"] = True
#     else:
#         state["needs_retry"] = False
#     return state
#
# # Edge that loops back if retry needed
# edges = [
#     Edge(source="bio", target="quality"),
#     Edge(source="quality", target="bio", condition=lambda s: s["needs_retry"]),
#     Edge(source="quality", target="END", condition=lambda s: not s["needs_retry"]),
# ]
#
# graph = Graph(
#     nodes=[bio_node, Node(fn=quality_check, name="quality")],
#     edges=edges,
#     start_node="bio"
# )
# ```
#
# Now the graph will keep calling the LLM until the simple quality predicate is satisfied (or you hit a max‑iteration limit you can enforce).
#
# ---
#
# ## 6️⃣ Persistence & Checkpointing
#
# Long‑running workflows (e.g., multi‑turn chat, data extraction pipelines) often need to survive restarts.
#
# ```python
# # Assume `graph` is already built
# state = State({"name": "Sujat", "step": "greeting"})
# graph.save_checkpoint(state, path="ckpt.json")   # writes JSON
#
# # Later…
# restored_state = graph.load_checkpoint(path="ckpt.json")
# graph.run(restored_state)   # resumes from where you left off
# ```
#
# - The checkpoint captures the entire mutable state **and** the current node position.
# - You can store checkpoints in a DB, S3, or any blob store; LangGraph only cares about the (de)serialization format.
#
# ---
#
# ## 7️⃣ Testing Your Graph
#
# Because nodes are pure functions (or at least deterministic given the same inputs), you can unit‑test them in isolation:
#
# ```python
# def test_generate_bio():
#     dummy_state = State({"name": "Alice"})
#     # Patch the OpenAI client with a mock that returns a known string
#     with patch("openai.OpenAI.chat.completions.create") as mock:
#         mock.return_value.choices[0].message.content = "Alice is a software engineer who loves hiking."
#         out = generate_bio(dummy_state)
#     assert out["bio"] == "Alice is a software engineer who loves hiking."
# ```
#
# Testing the **graph** itself is also straightforward:
#
# ```python
# def test_branching():
#     g = build_my_graph()   # returns the Graph instance
#     result = g.run(State({"name": "Bob", "detail": "short"}))
#     assert "short" in result["bio"].lower()
# ```
#
# ---
#
# ## 8️⃣ Where to Go Next
#
# | Resource | What You’ll Find |
# |----------|------------------|
# | **Official Docs** | Full API reference, advanced patterns (sub‑graphs, async execution). |
# | **LangGraph GitHub** | Example repos, issue tracker, community discussions. |
# | **Tutorial Notebook** | A Colab/Jupyter notebook that walks through a multi‑step chatbot with memory, tool use, and persistence. |
# | **Discord / Slack Community** | Quick help, showcase projects, and occasional “office hours” with the core maintainers. |
# | **Blog Posts** | Real‑world case studies (e.g., automated report generation, multi‑agent negotiation). |
#
# ---
#
# ## 9️⃣ Quick “Starter Project” Idea
#
# **Goal**: Build a *personalized travel itinerary generator*.
#
# 1. **Node 1 – Gather Preferences** (ask user for destination, travel dates, activity interests).
# 2. **Node 2 – Retrieve Data** (call a mock API or a real travel‑info endpoint).
# 3. **Node 3 – LLM Draft** (prompt the LLM to produce a day‑by‑day plan).
# 4. **Node 4 – Quality Check** (ensure each day includes at least one activity from the user’s interest list).
# 5. **Node 5 – Refine Loop** (if check fails, ask LLM to rewrite).
# 6. **Node 6 – Output** (render as markdown or JSON).
#
# Wire them together with conditional edges and a checkpoint after Node 2 so the user can pause and resume later.
#
# ---
#
# ## 10️⃣ Your Next Steps
#
# 1. **Clone the starter repo** (if you haven’t already) and run the `hello_world.py` script.
# 2. **Add an LLM node** using the OpenAI snippet above.
# 3. **Experiment with a conditional edge**—maybe route to a “fallback” node if the LLM returns an empty string.
# 4. **Persist a checkpoint** after the first node, then kill the process and reload it to see the resume in action.
# 5. **Write a unit test** for at least one node; this will cement the “pure function” mindset that makes LangGraph so composable.
#
# ---
#
# ### Need More Help?
#
# - **Specific question**: If you’re stuck on a particular API call or error message, paste the traceback and I can walk you through it.
# - **Design advice**: Want to model a more complex workflow (e.g., multi‑agent negotiation)? I can sketch a graph layout for you.
# - **Tool integration**: Need to call a database, a web scraper, or a custom Python library from a node? I can show the pattern.
#
# Just let me know what you’d like to dive into next! 🚀
# ------------------------------------------------------------------------------------------------------------------------
# Can you explain short term memory?
# ------------------------------------------------------------------------------------------------------------------------
# **Short‑term memory (STM)** is a mental system that holds a small amount of information in an active, readily accessible state for a brief period of time—typically on the order of seconds to a minute. It’s the “scratch‑pad” of the brain that lets you keep track of what you’re doing right now, such as remembering a phone number long enough to dial it or holding the last few words of a sentence while you understand its meaning.
#
# Below is a concise overview of the key features, mechanisms, and practical implications of short‑term memory.
#
# ---
#
# ## 1. Core Characteristics
#
# | Feature | Typical Value | What It Means |
# |---------|----------------|----------------|
# | **Capacity** | 7 ± 2 items (Miller’s classic estimate) | Most people can hold about 5–9 discrete “chunks” of information at once. A “chunk” can be a single digit, a word, or a meaningful group (e.g., a familiar acronym). |
# | **Duration** | 15–30 seconds without rehearsal | If you don’t actively repeat or rehearse the information, it fades quickly. |
# | **Encoding** | Primarily **acoustic** (sound) and **visual** (spatial) | You tend to remember a string of numbers by hearing them (acoustic) or a pattern of shapes by seeing them (visual). |
# | **Retrieval** | Immediate, automatic | Because the information is still “online,” you can pull it out with little effort. |
#
# ---
#
# ## 2. How It Works: The Process Flow
#
# 1. **Sensory Input** – Raw data from the senses (e.g., hearing a spoken word) first lands in **sensory memory** (a very brief buffer lasting < 1 second).
# 2. **Attention & Transfer** – If you attend to the stimulus, it moves into short‑term memory.
# 3. **Maintenance (Rehearsal)** – You can keep the info alive by:
#    - **Subvocal rehearsal** (silently repeating a phone number).
#    - **Chunking** (grouping digits into meaningful units).
# 4. **Decay or Displacement** – Without rehearsal, the trace fades (decay). New incoming items can also push older ones out (interference).
# 5. **Encoding to Long‑Term Memory** – With sufficient rehearsal and meaningful connections, the information may be consolidated into long‑term memory (LTM) via processes like **semantic encoding** and **sleep‑dependent consolidation**.
#
# ---
#
# ## 3. Brain Structures Involved
#
# | Region | Role in STM |
# |--------|-------------|
# | **Prefrontal Cortex (PFC)** | Executive control, manipulation of information (working memory). |
# | **Parietal Cortex** | Spatial and attentional aspects of STM. |
# | **Temporal Lobe (especially the auditory cortex)** | Acoustic encoding of verbal material. |
# | **Hippocampus** | Not essential for pure STM, but crucial for transferring information to LTM. |
# | **Basal Ganglia & Cerebellum** | Support procedural aspects of rehearsal (e.g., motor planning for subvocal speech). |
#
# Neuroimaging studies show that when you hold a string of letters in mind, the dorsolateral prefrontal cortex lights up, reflecting the active maintenance of that information.
#
# ---
#
# ## 4. Short‑Term vs. Working Memory
#
# - **Short‑term memory** is often used as a synonym for the *storage* component of the system.
# - **Working memory** expands the concept to include *manipulation* of the stored information (e.g., solving a mental arithmetic problem).
#   - Baddeley’s model of working memory includes:
#     1. **Phonological loop** (verbal STM).
#     2. **Visuospatial sketchpad** (visual‑spatial STM).
#     3. **Central executive** (attention control).
#     4. **Episodic buffer** (integrates information across modalities).
#
# Thus, STM can be thought of as the “raw storage” part of a broader working‑memory system.
#
# ---
#
# ## 5. Factors That Influence STM Performance
#
# | Factor | Effect |
# |--------|--------|
# | **Chunking** | Increases effective capacity (e.g., remembering “1776” as a single year rather than four separate digits). |
# | **Rehearsal** | Extends duration; the classic “repeat‑until‑you‑forget” strategy. |
# | **Interference** | Similar items can cause confusion (e.g., trying to remember two similar phone numbers back‑to‑back). |
# | **Attention** | Divided attention reduces the amount that can be stored. |
# | **Aging & Neurological Conditions** | Normal aging modestly reduces capacity; conditions like ADHD, traumatic brain injury, or early‑stage Alzheimer’s can cause more pronounced deficits. |
# | **Stress & Fatigue** | Impair the prefrontal cortex, leading to poorer maintenance. |
#
# ---
#
# ## 6. Practical Tips to Boost Short‑Term Memory
#
# 1. **Chunk Strategically** – Group information into meaningful units (e.g., “NY‑C” instead of “N‑Y‑C”).
# 2. **Use Mnemonic Devices** – Acronyms, rhymes, or visual imagery can create richer, more durable traces.
# 3. **Engage Multiple Modalities** – Say the information out loud *and* write it down; the combination of auditory and visual encoding helps.
# 4. **Practice Retrieval** – Testing yourself (even briefly) strengthens the memory trace more than passive review.
# 5. **Limit Distractions** – Reduce background noise and multitasking while you need to retain information.
# 6. **Stay Physically Healthy** – Adequate sleep, regular aerobic exercise, and a balanced diet (especially omega‑3 fatty acids) support prefrontal‑cortex function.
#
# ---
#
# ## 7. Quick Example: Remembering a Phone Number
#
# 1. **Hear** the number: 555‑236‑8745.
# 2. **Chunk** it: (555)‑(236‑8745) → three groups instead of ten digits.
# 3. **Rehearse** silently: “Five‑five‑five, two‑three‑six, eight‑seven‑four‑five.”
# 4. **Visualize** the keypad pattern or imagine the number on a piece of paper.
# 5. **Store** it in STM for ~30 seconds, then **encode** it into LTM by associating it with a person or a purpose (e.g., “my dentist’s office”).
#
# ---
#
# ### TL;DR
#
# - **Short‑term memory** holds ~5–9 chunks of information for ~15–30 seconds.
# - It relies on attention, rehearsal, and brain regions like the prefrontal cortex.
# - Chunking, rehearsal, and minimizing interference can dramatically improve its effectiveness.
# - It serves as the gateway for information that may later become part of long‑term memory.
#
# Feel free to ask if you’d like more detail on any specific aspect—e.g., the neurobiology, experimental paradigms used to study STM, or strategies for particular learning contexts!
# ------------------------------------------------------------------------------------------------------------------------
# What is my name?
# ------------------------------------------------------------------------------------------------------------------------
# I don’t have any information about your name. If you’d like me to address you a certain way, just let me know!
# ------------------------------------------------------------------------------------------------------------------------
