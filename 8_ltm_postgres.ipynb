# %%
! pip install -U "psycopg[binary,pool]" langgraph langgraph-checkpoint-postgres

# %%
from dotenv import load_dotenv
load_dotenv()

import uuid
from typing import List
from pydantic import BaseModel, Field

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage
from langchain_core.runnables import RunnableConfig

from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.store.postgres import PostgresStore
from langgraph.store.base import BaseStore

# %%
# ----------------------------
# 2) System prompt
# ----------------------------
SYSTEM_PROMPT_TEMPLATE = """You are a helpful assistant with memory capabilities.
If user-specific memory is available, use it to personalize 
your responses based on what you know about the user.

Your goal is to provide relevant, friendly, and tailored 
assistance that reflects the user’s preferences, context, and past interactions.

If the user’s name or relevant personal context is available, always personalize your responses by:
    – Always Address the user by name (e.g., "Sure, Nitish...") when appropriate
    – Referencing known projects, tools, or preferences (e.g., "your MCP server python based project")
    – Adjusting the tone to feel friendly, natural, and directly aimed at the user

Avoid generic phrasing when personalization is possible.

Use personalization especially in:
    – Greetings and transitions
    – Help or guidance tailored to tools and frameworks the user uses
    – Follow-up messages that continue from past context

Always ensure that personalization is based only on known user details and not assumed.

In the end suggest 3 relevant further questions based on the current response and user profile

The user’s memory (which may be empty) is provided as: {user_details_content}
"""

# %%
# ----------------------------
# 3) Memory extraction LLM
# ----------------------------
#memory_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
load_dotenv()
from langchain_groq import ChatGroq
# Model
memory_llm = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0.1)

# %%
class MemoryItem(BaseModel):
    text: str = Field(description="Atomic user memory")
    is_new: bool = Field(description="True if new, false if duplicate")

# %%
class MemoryDecision(BaseModel):
    should_write: bool
    memories: List[MemoryItem] = Field(default_factory=list)

# %%
memory_extractor = memory_llm.with_structured_output(MemoryDecision)

# %%
MEMORY_PROMPT = """You are responsible for updating and maintaining accurate user memory.

CURRENT USER DETAILS (existing memories):
{user_details_content}

TASK:
- Review the user's latest message.
- Extract user-specific info worth storing long-term (identity, stable preferences, ongoing projects/goals).
- For each extracted item, set is_new=true ONLY if it adds NEW information compared to CURRENT USER DETAILS.
- If it is basically the same meaning as something already present, set is_new=false.
- Keep each memory as a short atomic sentence.
- No speculation; only facts stated by the user.
- If there is nothing memory-worthy, return should_write=false and an empty list.
"""

# %%
# ----------------------------
# 3) Nodes
# ----------------------------
def remember_node(state: MessagesState, config: RunnableConfig, *, store: BaseStore):
    user_id = config["configurable"]["user_id"]
    ns = ("user", user_id, "details")

    # existing memory (all items under namespace)
    items = store.search(ns)
    existing = "\n".join(it.value.get("data", "") for it in items) if items else "(empty)"

    # latest user message
    last_text = state["messages"][-1].content

    decision: MemoryDecision = memory_extractor.invoke(
        [
            SystemMessage(content=MEMORY_PROMPT.format(user_details_content=existing)),
            {"role": "user", "content": last_text},
        ]
    )

    if decision.should_write:
        for mem in decision.memories:
            if mem.is_new and mem.text.strip():
                store.put(ns, str(uuid.uuid4()), {"data": mem.text.strip()})

    return {}

# %%
chat_llm = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0.1)

# %%
def chat_node(state: MessagesState, config: RunnableConfig, *, store: BaseStore):
    user_id = config["configurable"]["user_id"]
    ns = ("user", user_id, "details")

    items = store.search(ns)
    user_details = "\n".join(it.value.get("data", "") for it in items) if items else ""

    system_msg = SystemMessage(
        content=SYSTEM_PROMPT_TEMPLATE.format(user_details_content=user_details or "(empty)")
    )

    response = chat_llm.invoke([system_msg] + state["messages"])
    return {"messages": [response]}

# %%
# ----------------------------
# 4) Build graph
# ----------------------------
builder = StateGraph(MessagesState)
builder.add_node("remember", remember_node)
builder.add_node("chat", chat_node)
builder.add_edge(START, "remember")
builder.add_edge("remember", "chat")
builder.add_edge("chat", END)

# %%
# ----------------------------
# 5) Use PostgresStore (PERSISTENT LTM)
# ----------------------------
DB_URI = "postgresql://postgres:postgres@localhost:5442/postgres?sslmode=disable"

with PostgresStore.from_conn_string(DB_URI) as store:
    # IMPORTANT: run ONCE the first time you use this database
    store.setup()

    graph = builder.compile(store=store)

    config = {"configurable": {"user_id": "u1"}}

    graph.invoke({"messages": [{"role": "user", "content": "Hi, my name is Sujat"}]}, config)
    graph.invoke({"messages": [{"role": "user", "content": "I am learning data science"}]}, config)

    out = graph.invoke({"messages": [{"role": "user", "content": "Explain GenAI simply"}]}, config)
    print(out["messages"][-1].content)

    print("\n--- Stored Memories (from Postgres) ---")
    for it in store.search(("user", "u1", "details")):
        print(it.value["data"])
# Out:
# Sure, Sujat — let’s break down Generative AI (Gen AI) in the simplest terms.
#
# ---
#
# ## What is Generative AI?
#
# **Generative AI** is a type of artificial intelligence that can **create new content**—text, images, music, code, or even video—rather than just analyzing or classifying existing data.
#
# | Traditional AI | Generative AI |
# |----------------|---------------|
# | *What is this?* (e.g., “Is this email spam?”) | *Make something new* (e.g., “Write a short story about a robot”) |
# | Predictive, discriminative | Creative, constructive |
#
# ---
#
# ## How Does It Work? (A High‑Level View)
#
# 1. **Training on Lots of Data**
#    The model sees massive amounts of examples (e.g., billions of words, millions of pictures).
# 2. **Learning Patterns**
#    It learns statistical relationships—how words follow each other, how pixels combine into objects, etc.
# 3. **Generating New Samples**
#    When you give it a prompt, it samples from those learned patterns to produce something that *looks* like the training data but is brand‑new.
#
# Think of it like a **very advanced autocomplete** that can continue a sentence, draw a picture, or write code based on the context you provide.
#
# ---
#
# ## Core Building Blocks
#
# | Component | What It Does | Popular Example |
# |-----------|--------------|-----------------|
# | **Transformer Architecture** | Handles sequences (text, code) efficiently; captures long‑range dependencies. | GPT‑4, BERT |
# | **Diffusion Models** | Gradually “denoise” random noise into a coherent image. | Stable Diffusion, DALL·E 2 |
# | **Variational Autoencoders (VAEs)** | Encode data into a compact latent space, then decode to generate new samples. | Early image generators |
# | **Reinforcement Learning from Human Feedback (RLHF)** | Fine‑tunes the model to follow human preferences (e.g., being helpful, safe). | ChatGPT’s alignment process |
#
# ---
#
# ## Everyday Examples You Might Have Seen
#
# | Domain | What Gen AI Produces | Example Service |
# |--------|----------------------|-----------------|
# | Text   | Articles, code, chat replies | ChatGPT, Copilot |
# | Images | Paintings, photorealistic pictures | DALL·E, Midjourney |
# | Audio  | Music, voiceovers | Jukebox, Riffusion |
# | Video  | Short clips, animations | RunwayML, Sora (experimental) |
#
# ---
#
# ## Why It Matters for a Data‑Science Learner
#
# 1. **Data Augmentation** – Generate synthetic data to boost model training when real data is scarce.
# 2. **Rapid Prototyping** – Use code‑generation tools (e.g., GitHub Copilot) to scaffold notebooks or pipelines faster.
# 3. **Exploratory Analysis** – Ask a Gen AI to explain statistical concepts, suggest visualizations, or write pandas code on the fly.
# 4. **Ethical Awareness** – Understanding how these models learn helps you spot bias, privacy issues, and misuse.
#
# ---
#
# ## A Simple Analogy
#
# Imagine you’re learning to write poetry by reading thousands of poems. After enough exposure, you start to **imitate** the style, rhythm, and imagery you’ve seen. Gen AI does the same, but at a massive scale and with many more “languages” (text, images, sound).
#
# ---
#
# ## Quick “Hello World” of Gen AI (Python)
#
# If you want to try a tiny text generator right now, you can use the `transformers` library:
#
# ```python
# !pip install transformers torch   # run once
#
# from transformers import pipeline
#
# # Load a small, free model (GPT‑2)
# generator = pipeline("text-generation", model="gpt2")
#
# prompt = "Sujat is learning data science and wonders"
# result = generator(prompt, max_length=50, num_return_sequences=1)
#
# print(result[0]["generated_text"])
# ```
#
# *What happens?* The model continues the sentence based on patterns it learned from internet text. It’s a miniature taste of Gen AI.
#
# ---
#
# ## TL;DR
#
# - **Generative AI** creates new content by learning patterns from huge datasets.
# - It uses architectures like **transformers** (for text) and **diffusion models** (for images).
# - For a data‑science student, it can help with data augmentation, code assistance, and rapid experimentation—while also raising important ethical questions.
#
# ---
#
# ### What would you like to explore next?
#
# 1. **How can you use generative AI for data augmentation in a machine‑learning project?**
# 2. **What are the main ethical concerns with deploying Gen AI models, and how can you mitigate them?**
# 3. **Would you like a hands‑on tutorial on using a specific Gen AI tool (e.g., ChatGPT, Stable Diffusion) within a Python notebook?**
#
# Feel free to pick any, or let me know another angle you’re curious about!
#
# --- Stored Memories (from Postgres) ---
# The user is learning data science.
# The user’s name is Sujat.

# %% [markdown]
# ## Check Persistence

# %%
from langgraph.store.postgres import PostgresStore

DB_URI = "postgresql://postgres:postgres@localhost:5442/postgres?sslmode=disable"

with PostgresStore.from_conn_string(DB_URI) as store:
    ns = ("user", "u1", "details")
    items = store.search(ns)

for it in items:
    print(it.value["data"])
# Out:
# The user is learning data science.
# The user’s name is Sujat.
